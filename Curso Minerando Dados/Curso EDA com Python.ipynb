# %% [markdown]
# # Análise Exploratória de Dados (Passo a passo com Python)

# %% [markdown]
# #### Olá, hoje resolvi fazer o curso do link abaixo:
#
# https://minerandodados.com.br/analise-exploratoria-de-dados-passo-a-passo-com-python/

# %% [markdown]
# #### Aqui vou colocar todos os pips que tive que fazer para instalar as bibliotecas
# - pip install pandas
# - pip install matplotlib
# - pip install seaborn
# - pip install folium

# %% [markdown]
# #### O curso não deixa muito claro de onde ele pegou os dados que ele usa no exemplo dele.
#
# Mas eu procurei e encontrei no site abaixo:
# https://www.consumidor.gov.br/pages/dadosabertos/externo/
#
# Você tem que ir na aba 3 e pegar os dados do 2 Semestre de 2016.

# %% [markdown]
# #### Nota: Comandos do jupyter-notebook

# %% [markdown]
#      Nota importante: Estou enferrujado no uso do jupyter-notebook, então ao longo do texto também deixarei anotações de comandos do jupyter!

# %% [markdown]
#     Se você for no Menu >> Help >> Keyboard Shortcuts vc verá uma lista de comandos. A idéia é criar familiaridade com esses comandos para produzir jupyter-notebooks com maior agilidade e não precisar tanto usar o mouse.
#
#     Pra começar: ENTER entra na célula, ESC. Sai.
#
#     ENTER: Vc entra no modo de edição;
#     ESC: Vc entra no modo de comando;
#
#     Então, no modo de comando, já vamos começar aprendendo pelo menos os atalhos a seguir:
#         Y : change cell to code
#         M : change cell to markdown
#         1 : change cell to heading 1
#         2 : change cell to heading 2
#         3 : change cell to heading 3
#         4 : change cell to heading 4
#         5 : change cell to heading 5
#         6 : change cell to heading 6
#         Shift-Enter : run cell, select below
#         Ctrl-Enter : run selected cells
#         Alt-Enter : run cell and insert below
#
#         A : insert cell above
#         B : insert cell below
#
#         H : show keyboard shortcuts
#
#     Ou seja, para crar prática. Um bom exercício é esquecer o mouse e tentar fazer tudo usando o teclado.
#     Se tiver dúvida, apertar H para relembrar os comandos.

# %% [markdown]
# #### Agora eu vou finalmente começar o curso

# %%
# Importando as bibliotecas:
import pandas as pd
# %matplotlib inline
# %pylab inline
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
dataset = pd.read_csv('2_semestre_2016.csv',sep=';',encoding='latin1')

# %%
# Vamos por parte!
dataset.head()
# Out:
#   Região  UF                Cidade Sexo        Faixa Etária Data Finalização  \
# 0     NE  PI   São Raimundo Nonato    M  entre 21 a 30 anos       30/07/2016
# 1     CO  GO  Aparecida de Goiânia    F  entre 21 a 30 anos       30/07/2016
# 2     SE  SP       Mogi das Cruzes    M  entre 41 a 50 anos       31/07/2016
# 3     SE  SP       Mogi das Cruzes    M  entre 41 a 50 anos       30/07/2016
# 4     SE  MG              Oliveira    F         até 20 anos       30/07/2016
#
#    Tempo Resposta Nome Fantasia  \
# 0             0.0           Tim
# 1             0.0           SKY
# 2             0.0           Tim
# 3             0.0           Tim
# 4             1.0           Tim
#
#                                  Segmento de Mercado  \
# 0  Operadoras de Telecomunicações (Telefonia, Int...
# 1  Operadoras de Telecomunicações (Telefonia, Int...
# 2  Operadoras de Telecomunicações (Telefonia, Int...
# 3  Operadoras de Telecomunicações (Telefonia, Int...
# ...

# %%
# Transposta da "cabeça"
dataset.head().T
# Out:
#                                                                         0  \
# Região                                                                 NE
# UF                                                                     PI
# Cidade                                                São Raimundo Nonato
# Sexo                                                                    M
# Faixa Etária                                           entre 21 a 30 anos
# Data Finalização                                               30/07/2016
# Tempo Resposta                                                          0
# Nome Fantasia                                                         Tim
# Segmento de Mercado     Operadoras de Telecomunicações (Telefonia, Int...
# Área                                                     Telecomunicações
# Assunto                                          Telefonia Móvel Pós-paga
# Grupo Problema                                     Cobrança / Contestação
# ...

# %% [markdown]
# #### Bate com o curso? Então vamos continuar!

# %% [markdown]
#  Cada linha da base de dados corresponde a uma reclamação feita pelo consumidor.
#
# Temos vários atributos como a cidade do consumidor, a faixa etária desse consumidor, o tempo de resposta em dias que a empresa leva para responder o consumidor, o nome fantasia das empresas entre outros.
#
# Vamos fazer algumas perguntas para os nossos dados e verificar se as nossas suposições são válidas ou não.

# %% [markdown]
# ### Qual o número de reclamações por Estado?

# %%
dataset.groupby('UF')['UF'].count()
# Out:
# UF
# AC      554
# AL      647
# AM     1026
# AP      173
# BA     8269
# CE     5362
# DF     7057
# ES     3612
# GO     4355
# MA     1572
# MG    14356
# MS     1548
# MT     4108
# PA     1721
# PB     1586
# PE     4192
# PI      908
# PR    15107
# RJ    16895
# RN     1238
# RO      565
# RR      220
# RS    14615
# SC     4898
# SE      750
# SP    44905
# TO     2345
# Name: UF, dtype: int64
